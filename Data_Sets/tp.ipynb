# %%
import numpy as np
import pandas as pd
import random

# %%
df=pd.read_csv('Dif_Format_dataset.csv')

# %%
p=[]
c=[]
for i in range(len(df)):
    p.append(df.loc[i].Prompt)
    c.append(df.loc[i].Completion)

# %%
n=random.randint(0,len(df))
p[n]+c[n]
# Out:
# 'Narrative: You greet Pearson.You: I mean that. Pearson: Yes, yes.'

# %%
len(p),len(c)
# Out:
# (304, 304)

# %%
f=open('extraHistPrompts.txt','r')
s=f.readline()
flag=False
cc=''
while s!='':
    if(s=='\n'):
        s=f.readline()
        continue
    s=s.rstrip('\n')
    if s.find('Narrative:')!=-1 or s.find('Action:')!=-1:
        if flag==True:
            c.append(cc)
            cc=''
        p.append(s)
        flag=True
    else:
        cc=cc+' '+s
    s=f.readline()
c.append(cc)

# %%
len(p),len(c)
# Out:
# (480, 480)

# %%
df=pd.DataFrame({'Prompt':p,'Completion':c})

# %%
df
# Out:
#                                         Prompt  \
# 0                 Action: You move past Dutch.
# 1                 Action: You walk into Dutch.
# 2    Action: You stand near Dutch for a while.
# 3    Action: You stand near Dutch for a while.
# 4    Action: You stand near Dutch for a while.
# ..                                         ...
# 475           Narrative: You antagonize Susan.
# 476           Narrative: You antagonize Susan.
# 477           Narrative: You antagonize Susan.
# 478           Narrative: You antagonize Susan.
# 479           Narrative: You antagonize Susan.
#
#                                             Completion
# 0                   Dutch: Good morning Arthur.{greet}
# 1                             You: Dont mind me Dutch.
# 2               Dutch: Can you give me some room here.
# 3                Dutch: Back up a bit will you.{angry}
# 4        Dutch: Why are you acting like a fool.{angry}
# ..                                                 ...
# 475   You: Susan, did you do something with your ha...
# 476   You: You're really getting on my nerves, Susa...
# 477   You: I don't know why Dutch keeps you around,...
# 478   You: Susan, why don't you go take a long walk...
# 479   You: You know, Susan, I heard you've been tal...
#
# [480 rows x 2 columns]
